# %% [markdown]
# #### Author:---> Abhishek Kumar
# #### Email:-----> abhiydv23096@gmail.com
# #### Project:---> IPL AUCTION 2025 SPEND BY EACH TEAM MINI PROJECT

# %% [markdown]
# ![alt text](<WhatsApp Image 2024-12-08 at 00.33.16_96416182.jpg>)

# %% [markdown]
# ![alt text](<WhatsApp Image 2024-12-08 at 00.33.17_687db4ef.jpg>)

# %% [markdown]
# ![alt text](<WhatsApp Image 2024-12-08 at 00.33.14_bd079007.jpg>)

# %%
# Importing necessary libraries
#Sample small size data to give brief overview
import pandas as pd
import matplotlib.pyplot as plt

# Data for IPL 2025 Auction
data = {
    'Team': ['Kolkata Knight Riders', 'Kolkata Knight Riders', 'Kolkata Knight Riders', 'Kolkata Knight Riders', 'Kolkata Knight Riders', 
             'Lucknow Super Giants', 'Lucknow Super Giants', 'Lucknow Super Giants', 'Lucknow Super Giants', 'Lucknow Super Giants',
             'Mumbai Indians', 'Mumbai Indians', 'Mumbai Indians', 'Mumbai Indians', 'Mumbai Indians'],
    'Player': ['Venkatesh Iyer', 'Anrich Nortje', 'Quinton De Kock', 'Angkrish Raghuvanshi', 'Spencer Johnson',
               'Rishabh Pant', 'Avesh Khan', 'Akash Deep', 'David Miller', 'Abdul Samad',
               'Trent Boult', 'Deepak Chahar', 'Will Jacks', 'Naman Dhir', 'Allah Ghazanfar'],
    'Base Price': ['₹2,00,00,000', '₹2,00,00,000', '₹2,00,00,000', '₹30,00,000', '₹2,00,00,000',
                   '₹2,00,00,000', '₹2,00,00,000', '₹1,00,00,000', '₹1,50,00,000', '₹30,00,000',
                   '₹2,00,00,000', '₹2,00,00,000', '₹2,00,00,000', '₹30,00,000', '₹75,00,000'],
    'Winning Bid': ['₹23,75,00,000', '₹6,50,00,000', '₹3,60,00,000', '₹3,00,00,000', '₹2,80,00,000',
                    '₹27,00,00,000', '₹9,75,00,000', '₹8,00,00,000', '₹7,50,00,000', '₹4,20,00,000',
                    '₹12,50,00,000', '₹9,25,00,000', '₹5,25,00,000', '₹5,25,00,000', '₹4,80,00,000'],
    'Capped/Uncapped': ['Capped', 'Capped', 'Capped', 'Uncapped', 'Capped', 'Capped', 'Capped', 'Capped', 'Capped', 'Uncapped',
                        'Capped', 'Capped', 'Capped', 'Uncapped', 'Capped']
}

# Creating a dataframe
df = pd.DataFrame(data)

# Displaying the data
df

# Analysis of Total Spend by Each Team
team_spending = df.groupby('Team')['Winning Bid'].apply(lambda x: x.str.replace('₹','').str.replace(',','').astype(float).sum()).reset_index()

# Plotting total spend by each team
plt.figure(figsize=(10,6))
plt.bar(team_spending['Team'], team_spending['Winning Bid'], color='teal')
plt.xlabel('Team')
plt.ylabel('Total Spend (₹)')
plt.title('Total IPL 2025 Auction Spend by Each Team')
plt.xticks(rotation=45, ha='right')
plt.show()
